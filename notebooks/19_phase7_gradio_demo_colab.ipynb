# %% [markdown]
# # Phase 7: Gradio demo launcher
#
# This notebook launches the Phase 7 Gradio demo in Colab.
#
# Run this after the Phase 7 app code has been pushed to the GitHub repository used below. The app itself lives in `app/demo.py`.

# %% [markdown]
# ## Step 1: Connect Google Drive
#
# Drive is used for datasets and model checkpoints.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Step 2: Prepare the repository
#
# This clones or updates the repository, then installs the project requirements.

# %%
import subprocess
import sys
from pathlib import Path

REPO_URL = 'https://github.com/divinesta/SuperResolution-Comparative-Analysis.git'
REPO_ROOT = Path('/content/SuperResolution-Comparative-Analysis')
if REPO_ROOT.exists():
    subprocess.run(['git', '-C', str(REPO_ROOT), 'pull', '--ff-only'], check=True)
else:
    subprocess.run(['git', 'clone', REPO_URL, str(REPO_ROOT)], check=True)

subprocess.run(
    [sys.executable, '-m', 'pip', 'install', '-q', '-r', str(REPO_ROOT / 'requirements.txt')],
    check=True,
)
print('Repository and requirements ready.')

# %% [markdown]
# ## Step 3: Launch the demo
#
# The `--share` option creates a temporary public Gradio link. Use that link for supervisor/demo viewing.

# %%
subprocess.run(
    [sys.executable, '-m', 'app.demo', '--share'],
    cwd=str(REPO_ROOT),
    check=True,
)
